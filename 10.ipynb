# %%
#complete program
from random import choice

rps_dict = {'r': 'rock', 'p': 'paper', 's': 'scissors'}
wins=0
losses=0
ties=0

input("\t\tAdapted by the big PAPA!           [press Enter]")

while True:
    cpu_choice = choice(list(rps_dict.keys()))
    rps = input('\nChoose [r]ock, [p]aper or [s]cissors! ')
    
    if rps == ('s') or rps== ('r') or rps == ('p'):
        print('\n\t     CPU chose '+rps_dict[cpu_choice]+'!')
        if rps=='r':
            if cpu_choice == 'p':
                print('\n\t\tYou lost!')
                losses+=1
            elif cpu_choice == 's':
                print('\n\t\tYou won!')
                wins+=1
            else:
                print('\n\t\tIt\'s a tie!')
                ties+=1
        if rps=='p':
            if cpu_choice == 'r':
                print('\n\t\tYou won!')
                wins+=1
            elif cpu_choice == 's':
                print('\n\t\tYou lost!')
                losses+=1
            else:
                print('\n\t\tIt\'s a tie!')
                ties+=1
        if rps=='s':
            if cpu_choice == 'r':
                print('\n\t\tYou lost!')
                losses+=1
            elif cpu_choice == 'p':
                print('\n\t\tYou won!')
                wins+=1
            else:
                print('\n\t\tIt\'s a tie!')
                ties+=1
    if rps != 's' and rps!= 'r' and rps!= 'p':            
        while rps != "s" and rps!= "p" and rps!= "r":
            c = input("Please select either: p, r, s.\n\t\t\tAnswer: ")
            if c == "p" or c=="s" or c== "r":
                print("Finally a wise choice!")
                break
        if c== ('s') or ('r') or ('p'):
            print('\n\t     CPU chose '+rps_dict[cpu_choice]+'!')
            if c=='r':
                if cpu_choice == 'p':
                        print('\n\t\tYou lost!')
                        losses+=1
                elif cpu_choice == 's':
                        print('\n\t\tYou won!')
                        wins+=1
                else:
                        print('\n\t\tIt\'s a tie!')
                        ties+=1
            if c=='p':
                if cpu_choice == 'r':
                        print('\n\t\tYou won!')
                        wins+=1
                elif cpu_choice == 's':
                        print('\n\t\tYou lost!')
                        losses+=1
                else:
                        print('\n\t\tIt\'s a tie!')
                        ties+=1
            if c=='s':
                if cpu_choice == 'r':
                        print('\n\t\tYou lost!')
                        losses+=1
                elif cpu_choice == 'p':
                        print('\n\t\tYou won!')
                        wins+=1
                else:
                        print('\n\t\tIt\'s a tie!')
                        ties+=1               
                                                                            
    if input('\nExit game?[y/n] ')=="y":
        print("\nYour Statistics are the following:")
        break
print('\tWins:   ',wins)
print('\tTies:   ',ties)
print('\tLosses: ',losses)
print('Thanks for playing, see you soon!')
# Out:
# 		Adapted by the big PAPA!           [press Enter]
#
# Choose [r]ock, [p]aper or [s]cissors! r
#
# 	     CPU chose paper!
#
# 		You lost!
#
# Exit game?[y/n] n
#
# Choose [r]ock, [p]aper or [s]cissors! q
# Please select either: p, r, s.
# 			Answer: s
# Finally a wise choice!
#
# 	     CPU chose paper!
#
# 		You won!
#
# Exit game?[y/n] y
#
# Your Statistics are the following:
# 	Wins:    1
# 	Ties:    0
# 	Losses:  1
# Thanks for playing, see you soon!

# %%
#easy program
from random import choice

rps_dict = {'r': 'rock', 'p': 'paper', 's': 'scissors'}
wins=0
losses=0
ties=0
leave='n'
while leave!='y':
    cpu_choice = choice(list(rps_dict.keys()))
    rps = input('Choose [r]ock, [p]aper or [s]cissors! ')
    print('CPU chose '+rps_dict[cpu_choice]+'!')
    if rps=='r':
        if cpu_choice == 'p':
            print('You lost!')
            losses+=1
        elif cpu_choice == 's':
            print('You won!')
            wins+=1
        else:
            print('It\'s a tie!')
            ties+=1
    if rps=='p':
        if cpu_choice == 'r':
            print('You won!')
            wins+=1
        elif cpu_choice == 's':
            print('You lost!')
            losses+=1
        else:
            print('It\'s a tie!')
            ties+=1
    if rps=='s':
        if cpu_choice == 'r':
            print('You lost!')
            losses+=1
        elif cpu_choice == 'p':
            print('You won!')
            wins+=1
        else:
            print('It\'s a tie!')
            ties+=1
    leave = input('Exit game?[y/n] ')
    if leave=="y":
        print("\nYour Statistics are the following:")
print('\tWins:   ',wins)
print('\tTies:   ',ties)
print('\tLosses: ',losses)
print('Thanks for playing, see you soon!')
# Out:
# Choose [r]ock, [p]aper or [s]cissors! 3
# CPU chose paper!
# Exit game?[y/n] y
#
# Your Statistics are the following:
# 	Wins:    0
# 	Ties:    0
# 	Losses:  0
# Thanks for playing, see you soon!

# %%
#other way but now with while True.
from random import choice

rps_dict = {'r': 'rock', 'p': 'paper', 's': 'scissors'}
wins=0
losses=0
ties=0

while True:
    cpu_choice = choice(list(rps_dict.keys()))
    rps = input('Choose [r]ock, [p]aper or [s]cissors! ')
    print('CPU chose '+rps_dict[cpu_choice]+'!')
    if rps=='r':
        if cpu_choice == 'p':
            print('You lost!')
            losses+=1
        elif cpu_choice == 's':
            print('You won!')
            wins+=1
        else:
            print('It\'s a tie!')
            ties+=1
    if rps=='p':
        if cpu_choice == 'r':
            print('You won!')
            wins+=1
        elif cpu_choice == 's':
            print('You lost!')
            losses+=1
        else:
            print('It\'s a tie!')
            ties+=1
    if rps=='s':
        if cpu_choice == 'r':
            print('You lost!')
            losses+=1
        elif cpu_choice == 'p':
            print('You won!')
            wins+=1
        else:
            print('It\'s a tie!')
            ties+=1
    if input('\nExit game?[y/n] ')=="y":
        print("\nYour Statistics are the following:")
        break
print('\tWins:   ',wins)
print('\tTies:   ',ties)
print('\tLosses: ',losses)
print('Thanks for playing, see you soon!')
# Out:
# Choose [r]ock, [p]aper or [s]cissors! r
# CPU chose paper!
# You lost!
#
# Exit game?[y/n] y
#
# Your Statistics are the following:
# 	Wins:    0
# 	Ties:    0
# 	Losses:  1
# Thanks for playing, see you soon!
